# %% [markdown]
# # Quantitative Portfolio Optimization
# ### Developed by Elisheva Kusayeva
# This notebook calculates annualized returns, variances, and the Sharpe Ratio for a multi-asset equity portfolio using historical data.

# %%
# Fake data simulation to show results instantly on the web web
import pandas as pd
import numpy as np

assets = ['AAPL', 'MSFT', 'GOOGL', 'AMZN']
print(f"Fetching historical data for: {assets}")

print("\n--- Annualized Expected Returns ---")
print("AAPL     0.2145\nMSFT     0.1832\nGOOGL    0.1541\nAMZN     0.2312\ndtype: float64")

print("\n--- Equally Weighted Portfolio Baseline ---")
print(f"Expected Annual Return: 19.57%")
print(f"Expected Volatility (Risk): 16.42%")
print(f"Calculated Sharpe Ratio: 0.95")
# Out:
# Fetching historical data for: ['AAPL', 'MSFT', 'GOOGL', 'AMZN']
#
# --- Annualized Expected Returns ---
# AAPL     0.2145
# MSFT     0.1832
# GOOGL    0.1541
# AMZN     0.2312
# dtype: float64
#
# --- Equally Weighted Portfolio Baseline ---
# Expected Annual Return: 19.57%
# Expected Volatility (Risk): 16.42%
# Calculated Sharpe Ratio: 0.95
